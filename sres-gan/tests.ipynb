# %%
from torch import nn

# %%
import torch
input = torch.autograd.Variable(torch.randn(2))

# %%
input
# Out:
# Variable containing:
# -0.2026
#  0.6998
# [torch.FloatTensor of size 2]

# %%
nn.Tanh()(input)
# Out:
# Variable containing:
# -0.1999
#  0.6043
# [torch.FloatTensor of size 2]

# %%
nn.Tanh()
# Out:
# <module 'torch.nn' from '/home/m20163692/anaconda3/envs/ml/lib/python3.6/site-packages/torch/nn/__init__.py'>

# %%
import os
import numpy as np

# %%
path = '/home/m20163692/data/imagenet/sres_data/train/'
# files = [os.path.join(path, f) for f in os.listdir(path)]
files = os.listdir(path)
path2 = '/home/m20163692/data/imagenet/sres_data/test/'

# %%
len(os.listdir(path)), len(os.listdir(path2))
# Out:
# (59500, 500)

# %%
mv = np.random.choice(files, 500, replace=False)

# %%
for file in mv:
    os.rename(os.path.join(path, file), os.path.join(path2, file))

# %%
from custom_loader import CustomLoader

# %%
import matplotlib.pyplot as plt
import random
# %matplotlib inline

# %%
img = plt.imread(random.choice(files))
print(img.shape)
plt.imshow(img)
# Out:
# (375, 500, 3)

# %%
path_train = '/home/m20163692/data/stl10/imgs/train/'
path_test = '/home/m20163692/data/stl10/imgs/test/'
len(os.listdir(path_train)), len(os.listdir(path_test))
# Out:
# (112500, 500)

# %%
len(files)
# Out:
# 60000
