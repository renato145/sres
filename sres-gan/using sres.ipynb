# %%
import cv2
from sres import SRES
import matplotlib.pyplot as plt
# %matplotlib inline

super_res = SRES()

img = cv2.imread('../P70301-102125.jpg')
img = cv2.resize(img, (133,100))
plt.imshow(img)
plt.show()
out = super_res.apply_cv2(img)
plt.imshow(out)
